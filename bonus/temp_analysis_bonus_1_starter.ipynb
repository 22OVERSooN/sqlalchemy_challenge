# %% [markdown]
# # Bonus: Temperature Analysis I

# %%
import pandas as pd
from datetime import datetime as dt

# %%
# "tobs" is "temperature observations"
df = pd.read_csv('hawaii_measurements.csv')
df.head()
# Out:
#        station        date  prcp  tobs
# 0  USC00519397  2010-01-01  0.08    65
# 1  USC00519397  2010-01-02  0.00    63
# 2  USC00519397  2010-01-03  0.00    74
# 3  USC00519397  2010-01-04  0.00    76
# 4  USC00519397  2010-01-06   NaN    73

# %%
# Convert the date column format from string to datetime
df['date'] = pd.to_datetime(df['date'])
df.head()
# Out:
#        station       date  prcp  tobs
# 0  USC00519397 2010-01-01  0.08    65
# 1  USC00519397 2010-01-02  0.00    63
# 2  USC00519397 2010-01-03  0.00    74
# 3  USC00519397 2010-01-04  0.00    76
# 4  USC00519397 2010-01-06   NaN    73

# %%
# Set the date column as the DataFrame index
df = df.set_index('date')
df
# Out:
#                 station  prcp  tobs
# date
# 2010-01-01  USC00519397  0.08    65
# 2010-01-02  USC00519397  0.00    63
# 2010-01-03  USC00519397  0.00    74
# 2010-01-04  USC00519397  0.00    76
# 2010-01-06  USC00519397   NaN    73
# ...                 ...   ...   ...
# 2017-08-19  USC00516128  0.09    71
# 2017-08-20  USC00516128   NaN    78
# 2017-08-21  USC00516128  0.56    76
# 2017-08-22  USC00516128  0.50    76
# 2017-08-23  USC00516128  0.45    76
#
# [19550 rows x 3 columns]

# %% [markdown]
# ### Compare June and December data across all years

# %%
from scipy.stats import ttest_rel

# %%
# Filter data for desired months
month_data = df.loc[(df.index.month >= 6) & (df.index.month <= 12)]
month_data
# Out:
#                 station  prcp  tobs
# date
# 2010-06-01  USC00519397  0.00    78
# 2010-06-02  USC00519397  0.01    76
# 2010-06-03  USC00519397  0.00    78
# 2010-06-04  USC00519397  0.00    76
# 2010-06-05  USC00519397  0.00    77
# ...                 ...   ...   ...
# 2017-08-19  USC00516128  0.09    71
# 2017-08-20  USC00516128   NaN    78
# 2017-08-21  USC00516128  0.56    76
# 2017-08-22  USC00516128  0.50    76
# 2017-08-23  USC00516128  0.45    76
#
# [11074 rows x 3 columns]

# %%
# Identify the average temperature for June
jun_data = df.loc[df.index.month == 6]
average_tem_j = jun_data['tobs'].mean().round(2)
print(f"The average temperature for June is {average_tem_j}")
# Out:
# The average temperature for June is 74.94

# %%
# Identify the average temperature for December
dec_data = df.loc[df.index.month == 12]
average_tem_d = dec_data['tobs'].mean().round(2)
print(f"The average temperature for December is {average_tem_d}")
# Out:
# The average temperature for December is 71.04

# %%
# Create collections of temperature data
jun_temp = jun_data['tobs']
dec_temp = dec_data['tobs']
jun_data
# Out:
#                 station  prcp  tobs
# date
# 2010-06-01  USC00519397  0.00    78
# 2010-06-02  USC00519397  0.01    76
# 2010-06-03  USC00519397  0.00    78
# 2010-06-04  USC00519397  0.00    76
# 2010-06-05  USC00519397  0.00    77
# ...                 ...   ...   ...
# 2017-06-26  USC00516128  0.02    79
# 2017-06-27  USC00516128  0.10    74
# 2017-06-28  USC00516128  0.02    74
# 2017-06-29  USC00516128  0.04    76
# 2017-06-30  USC00516128  0.20    75
#
# [1700 rows x 3 columns]

# %%
# Run unpaired t-test
stats.ttest_ind(jun_temp,dec_temp)
# Out:
# Ttest_indResult(statistic=31.60372399000329, pvalue=3.9025129038616655e-191)

# %% [markdown]
# ### Analysis

# %%
# I think i will run the unpaird dataset,
# because the jun's dataset is not has the same amount of data as dec
# if it's not the same amount, then paired t-test is meaningless
